# %%
import psycopg2 as psy
import pandas.io.sql as psql

# %%
con = psy.connect(host="192.168.0.10", dbname="test", user="test", password="test")

# %%
query = psql.read_sql("select pid, datname, usename , application_name, client_addr, state, query_start, query from pg_catalog.pg_stat_activity limit 10;", con)

# %%
query
# Out:
#     pid   datname   usename                        application_name  \
# 0   977      None      None
# 1   979      None  postgres
# 2  4556      test      test         DBeaver 7.2.0 - Main <postgres>
# 3  3764  postgres      test     DBeaver 7.2.0 - Metadata <postgres>
# 4  3766      test      test  DBeaver 7.2.0 - SQLEditor <Script.sql>
# 5  3768      test      test             DBeaver 7.2.0 - Main <test>
# 6  3770      test      test         DBeaver 7.2.0 - Metadata <test>
# 7  9136      test      test
# 8  9179      test      test
# 9   975      None      None
#
#     client_addr   state                      query_start  \
# 0          None    None                              NaT
# 1          None    None                              NaT
# 2     127.0.0.1    idle 2020-09-11 21:52:33.541429+00:00
# 3     127.0.0.1    idle 2020-09-11 21:43:55.094461+00:00
# 4     127.0.0.1    idle 2020-09-11 21:52:55.881626+00:00
# 5     127.0.0.1    idle 2020-09-11 21:43:55.169541+00:00
# 6     127.0.0.1    idle 2020-09-11 21:52:47.421761+00:00
# 7  192.168.0.10    idle                              NaT
# 8  192.168.0.10  active 2020-09-11 22:43:02.115251+00:00
# 9          None    None                              NaT
#
#                                                query
# 0
# 1
# 2                                   SHOW search_path
# 3  SELECT t.oid,t.*,c.relkind,format_type(nullif(...
# 4                                   SHOW search_path
# 5                                   SHOW search_path
# 6  SELECT t.oid,t.*,c.relkind,format_type(nullif(...
# 7
# 8  select pid, datname, usename , application_nam...
# 9
